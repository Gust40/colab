# %% [markdown]
# <a href="https://colab.research.google.com/github/Gust40/colab/blob/master/Lista6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Gustavo Ferreira da Silva
# Lista 6

import pandas as pd
import statistics
#Exercício 1

''' dados = {'Matemática':[60,58,73,51,54,75,48,72,75,83,62,52], 'Música':[80,62,70,83,62,92,79,88,54,82,64,69]}
df = pd.DataFrame(dados,columns = ['Matemática', 'Música'])
Corr = df.corr()
print(Corr)'''

#Exercício 2
#Resposta: Que há uma correlação fraca entre a idade da edição e o número de páginas do livro.

#Exercício 3
'''dados = {'Anos de serviço':[2,3,4,5,4,6,7,8,8,10], 'N. de clientes':[48,50,56,52,43,60,62,58,64,72]}
df = pd.DataFrame(dados,columns = ['Anos de serviço', 'N. de clientes'])
Corr = df.corr()
print(Corr)'''

#Exercício 4
''' dados = {'X':[12,16,18,20,28,30,40,48,50,54], 'Y':[7.2,7.4,7.0,6.5,6.6,6.7,6.0,5.6,6.0,5.5]}
df = pd.DataFrame(dados,columns = ['X', 'Y'])
Corr = df.corr()
print(Corr)'''

#Exercício 5
#A) Calcule a média e o desvio padrão para cada conjunto de dados.
#Conjunto 1
'''x = [10,8,13,9,11,14,6,4,12,7,5] 
y = [8.04,6.95,7.58,8.81,8.33,9.96,7.24,4.26,10.84,4.82,5.68]
print("A média de X é:", statistics.mean(x))
print("A média de Y é:", statistics.mean(y))
print("O desvio padrão de X é:", statistics.stdev(x))
print("O desvio padrão de Y é:", statistics.stdev(y))'''

#Conjunto 2
'''x = [10,8,13,9,11,14,6,4,12,7,5] 
y = [9.14,8.14,8.74,8.77,9.26,8.10,6.13,3.10,9.13,7.26,4.74]
print("A média de X é:", statistics.mean(x))
print("A média de Y é:", statistics.mean(y))
print("O desvio padrão de X é:", statistics.stdev(x))
print("O desvio padrão de Y é:", statistics.stdev(y))'''

#Conjunto 3
'''x = [10,8,13,9,11,14,6,4,12,7,5] 
y = [7.46,6.77,12.74,7.11,7.81,8.84,6.08,5.39,8.15,6.42,5.73]
print("A média de X é:", statistics.mean(x))
print("A média de Y é:", statistics.mean(y))
print("O desvio padrão de X é:", statistics.stdev(x))
print("O desvio padrão de Y é:", statistics.stdev(y))'''

#Conjunto 4
'''x = [8,8,8,8,8,8,8,19,8,8,8] 
y = [6.58,5.76,7.71,8.84,8.47,7.04,5.25,12.50,5.56,7.91,6.89]
print("A média de X é:", statistics.mean(x))
print("A média de Y é:", statistics.mean(y))
print("O desvio padrão de X é:", statistics.stdev(x))
print("O desvio padrão de Y é:", statistics.stdev(y))'''

#B) Calcule o coeficiente de correlação para cada conjunto de dados.
#Conjunto 1
'''dados = {'X':[10,8,13,9,11,14,6,4,12,7,5], 'Y':[8.04,6.95,7.58,8.81,8.33,9.96,7.24,4.26,10.84,4.82,5.68]}
df = pd.DataFrame(dados,columns = ['X', 'Y'])
Corr = df.corr()
print(Corr)'''

#Conjunto 2
'''dados = {'X':[10,8,13,9,11,14,6,4,12,7,5], 'Y':[9.14,8.14,8.74,8.77,9.26,8.10,6.13,3.10,9.13,7.26,4.74]}
df = pd.DataFrame(dados,columns = ['X', 'Y'])
Corr = df.corr()
print(Corr)'''

#Conjunto 3
'''dados = {'X':[10,8,13,9,11,14,6,4,12,7,5], 'Y':[7.46,6.77,12.74,7.11,7.81,8.84,6.08,5.39,8.15,6.42,5.73]}
df = pd.DataFrame(dados,columns = ['X', 'Y'])
Corr = df.corr()
print(Corr)'''

#Conjunto 4
'''dados = {'X':[8,8,8,8,8,8,8,19,8,8,8], 'Y':[6.58,5.76,7.71,8.84,8.47,7.04,5.25,12.50,5.56,7.91,6.89]}
df = pd.DataFrame(dados,columns = ['X', 'Y'])
Corr = df.corr()
print(Corr)'''

#Exercício 6
'''dados = {'Alimentação':[4,5,1,3,6,2], 'Exercícios':[1,3,2,4,5,6], 'Rodízio':[3,1,2,6,4,5]}
df = pd.DataFrame(dados,columns = ['Alimentação', 'Exercícios', 'Rodízio'])
Corr = df.corr()
print(Corr)'''
#Não confirma, pois o rodízio apresenta ausência de relacionamento linear.
